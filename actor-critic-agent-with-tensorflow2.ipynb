# %% [markdown]
# # Setup

# %%
import gym
import logging
import numpy as np
import tensorflow as tf
import tensorflow.keras.layers as kl
import tensorflow.keras.losses as kls
import tensorflow.keras.optimizers as ko

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print("TensorFlow Ver: ", tf.__version__)
print("Eager Execution:", tf.executing_eagerly())
# Out:
# TensorFlow Ver:  1.13.0-dev20190117
# Eager Execution: True

# %%
# eager by default!
print("1 + 2 + 3 + 4 + 5 =", tf.reduce_sum([1, 2, 3, 4, 5]))
# Out:
# 1 + 2 + 3 + 4 + 5 = tf.Tensor(15, shape=(), dtype=int32)

# %% [markdown]
# # Advantage Actor-Critic with TensorFlow 2.0

# %% [markdown]
# ## Policy & Value Model Class

# %%
class ProbabilityDistribution(tf.keras.Model):
    def call(self, logits):
        # sample a random categorical action from given logits
        return tf.squeeze(tf.random.categorical(logits, 1), axis=-1)

class Model(tf.keras.Model):
    def __init__(self, num_actions):
        super().__init__('mlp_policy')
        # no tf.get_variable(), just simple Keras API
        self.hidden1 = kl.Dense(128, activation='relu')
        self.hidden2 = kl.Dense(128, activation='relu')
        self.value = kl.Dense(1, name='value')
        # logits are unnormalized log probabilities
        self.logits = kl.Dense(num_actions, name='policy_logits')
        self.dist = ProbabilityDistribution()

    def call(self, inputs):
        # inputs is a numpy array, convert to Tensor
        x = tf.convert_to_tensor(inputs)
        # separate hidden layers from the same input tensor
        hidden_logs = self.hidden1(x)
        hidden_vals = self.hidden2(x)
        return self.logits(hidden_logs), self.value(hidden_vals)

    def action_value(self, obs):
        # executes call() under the hood
        logits, value = self.predict(obs)
        action = self.dist.predict(logits)
        # a simpler option, will become clear later why we don't use it
        # action = tf.random.categorical(logits, 1)
        return np.squeeze(action, axis=-1), np.squeeze(value, axis=-1)

# %% [markdown]
# ## Advantage Actor-Critic Agent Class

# %%
class A2CAgent:
    def __init__(self, model):
        # hyperparameters for loss terms, gamma is the discount coefficient
        self.params = {
            'gamma': 0.99,
            'value': 0.5,
            'entropy': 0.0001
        }
        self.model = model
        self.model.compile(
            optimizer=ko.RMSprop(lr=0.0007),
            # define separate losses for policy logits and value estimate
            loss=[self._logits_loss, self._value_loss]
        )
    
    def train(self, env, batch_sz=32, updates=1000):
        # storage helpers for a single batch of data
        actions = np.empty((batch_sz,), dtype=np.int32)
        rewards, dones, values = np.empty((3, batch_sz))
        observations = np.empty((batch_sz,) + env.observation_space.shape)
        # training loop: collect samples, send to optimizer, repeat updates times
        ep_rews = [0.0]
        next_obs = env.reset()
        for update in range(updates):
            for step in range(batch_sz):
                observations[step] = next_obs.copy()
                actions[step], values[step] = self.model.action_value(next_obs[None, :])
                next_obs, rewards[step], dones[step], _ = env.step(actions[step])

                ep_rews[-1] += rewards[step]
                if dones[step]:
                    ep_rews.append(0.0)
                    next_obs = env.reset()
                    logging.info("Episode: %03d, Reward: %03d" % (len(ep_rews)-1, ep_rews[-2]))

            _, next_value = self.model.action_value(next_obs[None, :])
            returns, advs = self._returns_advantages(rewards, dones, values, next_value)
            # a trick to input actions and advantages through same API
            acts_and_advs = np.concatenate([actions[:, None], advs[:, None]], axis=-1)
            # performs a full training step on the collected batch
            # note: no need to mess around with gradients, Keras API handles it
            losses = self.model.train_on_batch(observations, [acts_and_advs, returns])
            logging.debug("[%d/%d] Losses: %s" % (update+1, updates, losses))
        return ep_rews

    def test(self, env, render=False):
        obs, done, ep_reward = env.reset(), False, 0
        while not done:
            action, _ = self.model.action_value(obs[None, :])
            obs, reward, done, _ = env.step(action)
            ep_reward += reward
            if render:
                env.render()
        return ep_reward

    def _returns_advantages(self, rewards, dones, values, next_value):
        # next_value is the bootstrap value estimate of a future state (the critic)
        returns = np.append(np.zeros_like(rewards), next_value, axis=-1)
        # returns are calculated as discounted sum of future rewards
        for t in reversed(range(rewards.shape[0])):
            returns[t] = rewards[t] + self.params['gamma'] * returns[t+1] * (1-dones[t])
        returns = returns[:-1]
        # advantages are returns - baseline, value estimates in our case
        advantages = returns - values
        return returns, advantages
    
    def _value_loss(self, returns, value):
        # value loss is typically MSE between value estimates and returns
        return self.params['value']*kls.mean_squared_error(returns, value)

    def _logits_loss(self, acts_and_advs, logits):
        # a trick to input actions and advantages through same API
        actions, advantages = tf.split(acts_and_advs, 2, axis=-1)
        # polymorphic CE loss function that supports sparse and weighted options
        # from_logits argument ensures transformation into normalized probabilities
        cross_entropy = kls.CategoricalCrossentropy(from_logits=True)
        # policy loss is defined by policy gradients, weighted by advantages
        # note: we only calculate the loss on the actions we've actually taken
        # thus under the hood a sparse version of CE loss will be executed
        actions = tf.cast(actions, tf.int32)
        policy_loss = cross_entropy(actions, logits, sample_weight=advantages)
        # entropy loss can be calculated via CE over itself
        entropy_loss = cross_entropy(logits, logits)
        # here signs are flipped because optimizer minimizes
        return policy_loss - self.params['entropy']*entropy_loss

# %%
env = gym.make('CartPole-v0')
model = Model(num_actions=env.action_space.n)
model.action_value(env.reset()[None, :])
# Out:
# WARNING:tensorflow:From /home/inoryy/anaconda3/envs/tf2/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:655: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# (array(1), array([0.00197717], dtype=float32))

# %% [markdown]
# # Training A2C Agent & Results

# %%
env = gym.make('CartPole-v0')
model = Model(num_actions=env.action_space.n)
agent = A2CAgent(model)

# %% [markdown]
# ## Testing with Random Weights

# %%
rewards_sum = agent.test(env)
print("Total Episode Reward: %d out of 200" % agent.test(env))
# Out:
# Total Episode Reward: 12 out of 200

# %%
# set to logging.WARNING to disable logs or logging.DEBUG to see losses as well
logging.basicConfig(level=logging.INFO)

rewards_history = agent.train(env)
print("Finished training.")
# Out:
# INFO:root:Episode: 001, Reward: 019
# INFO:root:Episode: 002, Reward: 023
# INFO:root:Episode: 003, Reward: 027
# INFO:root:Episode: 004, Reward: 016
# INFO:root:Episode: 005, Reward: 035
# INFO:root:Episode: 006, Reward: 021
# INFO:root:Episode: 007, Reward: 012
# INFO:root:Episode: 008, Reward: 023
# INFO:root:Episode: 009, Reward: 021
# INFO:root:Episode: 010, Reward: 026
# INFO:root:Episode: 011, Reward: 059
# INFO:root:Episode: 012, Reward: 021
# INFO:root:Episode: 013, Reward: 012
# INFO:root:Episode: 014, Reward: 018
# INFO:root:Episode: 015, Reward: 016
# INFO:root:Episode: 016, Reward: 027
# INFO:root:Episode: 017, Reward: 032
# INFO:root:Episode: 018, Reward: 013
# INFO:root:Episode: 246, Reward: 133
# INFO:root:Episode: 247, Reward: 101
# INFO:root:Episode: 248, Reward: 043
# INFO:root:Episode: 249, Reward: 053
# INFO:root:Episode: 250, Reward: 065
# INFO:root:Episode: 251, Reward: 072
# INFO:root:Episode: 252, Reward: 093
# INFO:root:Episode: 253, Reward: 200
# INFO:root:Episode: 254, Reward: 156
# INFO:root:Episode: 255, Reward: 053
# INFO:root:Episode: 256, Reward: 057
# INFO:root:Episode: 257, Reward: 121
# INFO:root:Episode: 258, Reward: 051
# INFO:root:Episode: 259, Reward: 095
# INFO:root:Episode: 260, Reward: 096
# INFO:root:Episode: 261, Reward: 053
# INFO:root:Episode: 262, Reward: 193
# INFO:root:Episode: 263, Reward: 083
# INFO:root:Episode: 264, Reward: 060
# INFO:root:Episode: 265, Reward: 100
# INFO:root:Episode: 266, Reward: 113
# INFO:root:Episode: 267, Reward: 120
# INFO:root:Episode: 268, Reward: 038
# INFO:root:Episode: 269, Reward: 084
# INFO:root:Episode: 270, Reward: 049
# INFO:root:Episode: 271, Reward: 066
# INFO:root:Episode: 272, Reward: 166
# INFO:root:Episode: 273, Reward: 144
# INFO:root:Episode: 274, Reward: 053
# INFO:root:Episode: 275, Reward: 057
# INFO:root:Episode: 276, Reward: 092
# INFO:root:Episode: 277, Reward: 122
# INFO:root:Episode: 278, Reward: 153
# INFO:root:Episode: 279, Reward: 131
# INFO:root:Episode: 280, Reward: 200
# INFO:root:Episode: 281, Reward: 074
# INFO:root:Episode: 282, Reward: 147
# INFO:root:Episode: 283, Reward: 079
# INFO:root:Episode: 284, Reward: 120
# INFO:root:Episode: 285, Reward: 136
# INFO:root:Episode: 286, Reward: 133
# INFO:root:Episode: 287, Reward: 133
# INFO:root:Episode: 288, Reward: 088
# INFO:root:Episode: 289, Reward: 057
# INFO:root:Episode: 290, Reward: 185
# INFO:root:Episode: 291, Reward: 087
# INFO:root:Episode: 292, Reward: 154
# INFO:root:Episode: 293, Reward: 200
# INFO:root:Episode: 294, Reward: 114
# INFO:root:Episode: 295, Reward: 118
# INFO:root:Episode: 296, Reward: 089
# INFO:root:Episode: 297, Reward: 069
# INFO:root:Episode: 298, Reward: 155
# INFO:root:Episode: 299, Reward: 109
# INFO:root:Episode: 300, Reward: 095
# INFO:root:Episode: 301, Reward: 200
# INFO:root:Episode: 302, Reward: 200
# INFO:root:Episode: 303, Reward: 139
# INFO:root:Episode: 304, Reward: 200
# INFO:root:Episode: 305, Reward: 099
# INFO:root:Episode: 306, Reward: 133
# INFO:root:Episode: 307, Reward: 152
# INFO:root:Episode: 308, Reward: 177
# INFO:root:Episode: 309, Reward: 140
# INFO:root:Episode: 310, Reward: 167
# INFO:root:Episode: 311, Reward: 134
# INFO:root:Episode: 312, Reward: 200
# INFO:root:Episode: 313, Reward: 200
# INFO:root:Episode: 314, Reward: 154
# INFO:root:Episode: 315, Reward: 200
# INFO:root:Episode: 316, Reward: 141
# INFO:root:Episode: 317, Reward: 200
# INFO:root:Episode: 318, Reward: 072
# INFO:root:Episode: 319, Reward: 128
# INFO:root:Episode: 320, Reward: 190
# INFO:root:Episode: 321, Reward: 200
# INFO:root:Episode: 322, Reward: 108
# INFO:root:Episode: 323, Reward: 038
# INFO:root:Episode: 324, Reward: 200
# INFO:root:Episode: 325, Reward: 102
# INFO:root:Episode: 326, Reward: 200
# INFO:root:Episode: 327, Reward: 200
# INFO:root:Episode: 328, Reward: 200
# INFO:root:Episode: 329, Reward: 151
# INFO:root:Episode: 330, Reward: 200
# INFO:root:Episode: 331, Reward: 129
# INFO:root:Episode: 332, Reward: 086
# INFO:root:Episode: 333, Reward: 174
# INFO:root:Episode: 334, Reward: 157
# INFO:root:Episode: 335, Reward: 200
# INFO:root:Episode: 336, Reward: 060
# INFO:root:Episode: 337, Reward: 200
# INFO:root:Episode: 338, Reward: 200
# INFO:root:Episode: 339, Reward: 036
# INFO:root:Episode: 340, Reward: 111
# INFO:root:Episode: 341, Reward: 200
# INFO:root:Episode: 342, Reward: 200
# INFO:root:Episode: 343, Reward: 200
# INFO:root:Episode: 344, Reward: 193
# INFO:root:Episode: 345, Reward: 200
# INFO:root:Episode: 346, Reward: 174
# INFO:root:Episode: 347, Reward: 200
# INFO:root:Episode: 348, Reward: 146
# INFO:root:Episode: 349, Reward: 150
# INFO:root:Episode: 350, Reward: 146
# INFO:root:Episode: 351, Reward: 148
# INFO:root:Episode: 352, Reward: 144
# INFO:root:Episode: 353, Reward: 162
# INFO:root:Episode: 354, Reward: 200
# INFO:root:Episode: 355, Reward: 200
# INFO:root:Episode: 356, Reward: 133
# INFO:root:Episode: 357, Reward: 152
# INFO:root:Episode: 358, Reward: 096
# INFO:root:Episode: 359, Reward: 069
# INFO:root:Episode: 360, Reward: 039
# INFO:root:Episode: 361, Reward: 115
# INFO:root:Episode: 362, Reward: 130
# INFO:root:Episode: 363, Reward: 077
# INFO:root:Episode: 364, Reward: 128
# INFO:root:Episode: 365, Reward: 098
# INFO:root:Episode: 366, Reward: 129
# INFO:root:Episode: 367, Reward: 033
# INFO:root:Episode: 368, Reward: 200
# INFO:root:Episode: 369, Reward: 140
# INFO:root:Episode: 370, Reward: 155
# INFO:root:Episode: 371, Reward: 130
# INFO:root:Episode: 372, Reward: 167
# INFO:root:Episode: 373, Reward: 170
# INFO:root:Episode: 374, Reward: 180
# INFO:root:Episode: 375, Reward: 147
# INFO:root:Episode: 376, Reward: 114
# INFO:root:Episode: 377, Reward: 054
# INFO:root:Episode: 378, Reward: 200
# INFO:root:Episode: 379, Reward: 072
# INFO:root:Episode: 380, Reward: 200
# INFO:root:Episode: 381, Reward: 200
# INFO:root:Episode: 382, Reward: 200
# INFO:root:Episode: 383, Reward: 182
# INFO:root:Episode: 384, Reward: 200
# INFO:root:Episode: 385, Reward: 200
# INFO:root:Episode: 386, Reward: 193
# INFO:root:Episode: 387, Reward: 200
# INFO:root:Episode: 388, Reward: 095
# INFO:root:Episode: 389, Reward: 200
# INFO:root:Episode: 390, Reward: 125
# INFO:root:Episode: 391, Reward: 158
# INFO:root:Episode: 392, Reward: 148
# INFO:root:Episode: 393, Reward: 083
# INFO:root:Episode: 394, Reward: 200
# INFO:root:Episode: 395, Reward: 200
# INFO:root:Episode: 396, Reward: 200
# INFO:root:Episode: 397, Reward: 156
# INFO:root:Episode: 398, Reward: 068
# Finished training.

# %% [markdown]
# ## Testing with Trained Model

# %%
print("Total Episode Reward: %d out of 200" % agent.test(env))
# Out:
# Total Episode Reward: 200 out of 200

# %% [markdown]
# ## Training Rewards History

# %%
plt.style.use('seaborn')
plt.plot(np.arange(0, len(rewards_history), 25), rewards_history[::25])
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.show()

# %% [markdown]
# # Static Computational Graph

# %%
with tf.Graph().as_default():
    print("Eager Execution:", tf.executing_eagerly()) # False

    model = Model(num_actions=env.action_space.n)
    agent = A2CAgent(model)

    rewards_history = agent.train(env)
    print("Finished training, testing...")
    print("Total Episode Reward: %d out of 200" % agent.test(env))
# Out:
# Eager Execution: False
# WARNING:tensorflow:From /home/inoryy/anaconda3/envs/tf2/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1253: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/inoryy/anaconda3/envs/tf2/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1253: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:root:Episode: 001, Reward: 020
# WARNING:tensorflow:From /home/inoryy/anaconda3/envs/tf2/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer_utils.py:123: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/inoryy/anaconda3/envs/tf2/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer_utils.py:123: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:root:Episode: 002, Reward: 027
# INFO:root:Episode: 003, Reward: 032
# INFO:root:Episode: 004, Reward: 017
# INFO:root:Episode: 005, Reward: 012
# INFO:root:Episode: 006, Reward: 015
# INFO:root:Episode: 007, Reward: 025
# INFO:root:Episode: 008, Reward: 010
# INFO:root:Episode: 009, Reward: 026
# INFO:root:Episode: 010, Reward: 014
# INFO:root:Episode: 011, Reward: 054
# INFO:root:Episode: 012, Reward: 012
# INFO:root:Episode: 013, Reward: 038
# INFO:root:Episode: 014, Reward: 024
# INFO:root:Episode: 015, Reward: 022
# INFO:root:Episode: 016, Reward: 034
# INFO:root:Episode: 017, Reward: 072
# INFO:root:Episode: 018, Reward: 022
# INFO:root:Episode: 019, Reward: 029
# INFO:root:Episode: 020, Reward: 020
# INFO:root:Episode: 021, Reward: 017
# INFO:root:Episode: 022, Reward: 013
# INFO:root:Episode: 023, Reward: 067
# INFO:root:Episode: 024, Reward: 100
# INFO:root:Episode: 025, Reward: 056
# INFO:root:Episode: 026, Reward: 096
# INFO:root:Episode: 027, Reward: 019
# INFO:root:Episode: 028, Reward: 016
# INFO:root:Episode: 029, Reward: 023
# INFO:root:Episode: 030, Reward: 013
# INFO:root:Episode: 031, Reward: 020
# INFO:root:Episode: 032, Reward: 023
# INFO:root:Episode: 033, Reward: 026
# INFO:root:Episode: 034, Reward: 070
# INFO:root:Episode: 035, Reward: 033
# INFO:root:Episode: 036, Reward: 028
# INFO:root:Episode: 037, Reward: 059
# INFO:root:Episode: 038, Reward: 047
# INFO:root:Episode: 039, Reward: 026
# INFO:root:Episode: 040, Reward: 028
# INFO:root:Episode: 041, Reward: 034
# INFO:root:Episode: 042, Reward: 065
# INFO:root:Episode: 043, Reward: 014
# INFO:root:Episode: 044, Reward: 028
# INFO:root:Episode: 045, Reward: 018
# INFO:root:Episode: 046, Reward: 011
# INFO:root:Episode: 047, Reward: 011
# INFO:root:Episode: 048, Reward: 020
# INFO:root:Episode: 276, Reward: 112
# INFO:root:Episode: 277, Reward: 080
# INFO:root:Episode: 278, Reward: 195
# INFO:root:Episode: 279, Reward: 186
# INFO:root:Episode: 280, Reward: 036
# INFO:root:Episode: 281, Reward: 087
# INFO:root:Episode: 282, Reward: 133
# INFO:root:Episode: 283, Reward: 037
# INFO:root:Episode: 284, Reward: 114
# INFO:root:Episode: 285, Reward: 065
# INFO:root:Episode: 286, Reward: 031
# INFO:root:Episode: 287, Reward: 071
# INFO:root:Episode: 288, Reward: 168
# INFO:root:Episode: 289, Reward: 121
# INFO:root:Episode: 290, Reward: 200
# INFO:root:Episode: 291, Reward: 046
# INFO:root:Episode: 292, Reward: 048
# INFO:root:Episode: 293, Reward: 100
# INFO:root:Episode: 294, Reward: 088
# INFO:root:Episode: 295, Reward: 158
# INFO:root:Episode: 296, Reward: 151
# INFO:root:Episode: 297, Reward: 037
# INFO:root:Episode: 298, Reward: 136
# INFO:root:Episode: 299, Reward: 096
# INFO:root:Episode: 300, Reward: 047
# INFO:root:Episode: 301, Reward: 121
# INFO:root:Episode: 302, Reward: 041
# INFO:root:Episode: 303, Reward: 128
# INFO:root:Episode: 304, Reward: 163
# INFO:root:Episode: 305, Reward: 181
# INFO:root:Episode: 306, Reward: 104
# INFO:root:Episode: 307, Reward: 121
# INFO:root:Episode: 308, Reward: 142
# INFO:root:Episode: 309, Reward: 200
# INFO:root:Episode: 310, Reward: 200
# INFO:root:Episode: 311, Reward: 198
# INFO:root:Episode: 312, Reward: 181
# INFO:root:Episode: 313, Reward: 062
# INFO:root:Episode: 314, Reward: 159
# INFO:root:Episode: 315, Reward: 123
# INFO:root:Episode: 316, Reward: 097
# INFO:root:Episode: 317, Reward: 200
# INFO:root:Episode: 318, Reward: 080
# INFO:root:Episode: 319, Reward: 070
# INFO:root:Episode: 320, Reward: 200
# INFO:root:Episode: 321, Reward: 095
# INFO:root:Episode: 322, Reward: 142
# INFO:root:Episode: 323, Reward: 138
# INFO:root:Episode: 324, Reward: 141
# INFO:root:Episode: 325, Reward: 175
# INFO:root:Episode: 326, Reward: 092
# INFO:root:Episode: 327, Reward: 124
# INFO:root:Episode: 328, Reward: 200
# INFO:root:Episode: 329, Reward: 113
# INFO:root:Episode: 330, Reward: 191
# INFO:root:Episode: 331, Reward: 177
# INFO:root:Episode: 332, Reward: 200
# INFO:root:Episode: 333, Reward: 074
# INFO:root:Episode: 334, Reward: 034
# INFO:root:Episode: 335, Reward: 159
# INFO:root:Episode: 336, Reward: 127
# INFO:root:Episode: 337, Reward: 200
# INFO:root:Episode: 338, Reward: 140
# INFO:root:Episode: 339, Reward: 135
# INFO:root:Episode: 340, Reward: 200
# INFO:root:Episode: 341, Reward: 200
# INFO:root:Episode: 342, Reward: 177
# INFO:root:Episode: 343, Reward: 187
# INFO:root:Episode: 344, Reward: 149
# INFO:root:Episode: 345, Reward: 191
# INFO:root:Episode: 346, Reward: 155
# INFO:root:Episode: 347, Reward: 157
# INFO:root:Episode: 348, Reward: 164
# INFO:root:Episode: 349, Reward: 158
# INFO:root:Episode: 350, Reward: 200
# INFO:root:Episode: 351, Reward: 138
# INFO:root:Episode: 352, Reward: 144
# INFO:root:Episode: 353, Reward: 147
# INFO:root:Episode: 354, Reward: 200
# INFO:root:Episode: 355, Reward: 145
# INFO:root:Episode: 356, Reward: 150
# INFO:root:Episode: 357, Reward: 062
# INFO:root:Episode: 358, Reward: 149
# INFO:root:Episode: 359, Reward: 187
# INFO:root:Episode: 360, Reward: 164
# INFO:root:Episode: 361, Reward: 144
# INFO:root:Episode: 362, Reward: 200
# INFO:root:Episode: 363, Reward: 200
# INFO:root:Episode: 364, Reward: 104
# INFO:root:Episode: 365, Reward: 127
# INFO:root:Episode: 366, Reward: 200
# INFO:root:Episode: 367, Reward: 111
# INFO:root:Episode: 368, Reward: 200
# INFO:root:Episode: 369, Reward: 200
# INFO:root:Episode: 370, Reward: 124
# INFO:root:Episode: 371, Reward: 200
# INFO:root:Episode: 372, Reward: 200
# INFO:root:Episode: 373, Reward: 178
# INFO:root:Episode: 374, Reward: 200
# INFO:root:Episode: 375, Reward: 200
# INFO:root:Episode: 376, Reward: 057
# INFO:root:Episode: 377, Reward: 166
# INFO:root:Episode: 378, Reward: 118
# INFO:root:Episode: 379, Reward: 200
# INFO:root:Episode: 380, Reward: 082
# INFO:root:Episode: 381, Reward: 118
# INFO:root:Episode: 382, Reward: 058
# INFO:root:Episode: 383, Reward: 200
# INFO:root:Episode: 384, Reward: 171
# INFO:root:Episode: 385, Reward: 113
# INFO:root:Episode: 386, Reward: 169
# INFO:root:Episode: 387, Reward: 103
# INFO:root:Episode: 388, Reward: 141
# INFO:root:Episode: 389, Reward: 191
# INFO:root:Episode: 390, Reward: 200
# INFO:root:Episode: 391, Reward: 171
# INFO:root:Episode: 392, Reward: 052
# INFO:root:Episode: 393, Reward: 171
# Finished training, testing...
# Total Episode Reward: 200 out of 200

# %% [markdown]
# # Benchmarks

# %%
# Note: comparing wall time isn't exactly fair due to specifics of how things are executed on multi-core CPU

# %%
env = gym.make('CartPole-v0')
obs = np.repeat(env.reset()[None, :], 100000, axis=0)

# %% [markdown]
# ## Eager Benchmark

# %%
# %%time

model = Model(env.action_space.n)
model.run_eagerly = True

print("Eager Execution:  ", tf.executing_eagerly())
print("Eager Keras Model:", model.run_eagerly)

_ = model(obs)
# _ = model.predict(obs)
# Out:
# Eager Execution:   True
# Eager Keras Model: True
# CPU times: user 639 ms, sys: 736 ms, total: 1.38 s
# Wall time: 116 ms

# %% [markdown]
# ## Static Benchmark

# %%
# %%time

with tf.Graph().as_default():
    model = Model(env.action_space.n)

    print("Eager Execution:  ", tf.executing_eagerly())
    print("Eager Keras Model:", model.run_eagerly)

    _ = model.predict(obs)
# Out:
# Eager Execution:   False
# Eager Keras Model: False
# CPU times: user 793 ms, sys: 79.7 ms, total: 873 ms
# Wall time: 656 ms

# %% [markdown]
# ## Default Benchmark

# %%
# %%time

model = Model(env.action_space.n)

print("Eager Execution:  ", tf.executing_eagerly())
print("Eager Keras Model:", model.run_eagerly)

_ = model.predict(obs)
# Out:
# Eager Execution:   True
# Eager Keras Model: False
# CPU times: user 994 ms, sys: 23.1 ms, total: 1.02 s
# Wall time: 769 ms
